# %%
# !pip install -q streamlit
# !npm install localtunnel
# !git clone https://github.com/1999mili/conAI_RAG.git
# !pip install -r conAI_RAG/requirements.txt
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 23 packages in 1s
# ⠇
# ⠇3 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠏fatal: destination path 'conAI_RAG' already exists and is not an empty directory.
# ...

# %%
# Copy the output --> will be used as password for the webpage
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.247.61.24

# %%
# This will generate the URL and click on it. Paste the above IP as the password
# that will redirect the page to the streamlit app
# !streamlit run conAI_RAG/app1.py &>/content/logs.txt &
# !npx localtunnel --port 8501
# Out:
# ⠙your url is: https://grumpy-emus-knock.loca.lt
# ^C
